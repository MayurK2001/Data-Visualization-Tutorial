# %%
import pandas as pd

# %%
from matplotlib import pyplot as plt

# %%
df = pd.read_csv("Flipkart_Mobile.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-7220d288f9a6> in <module>
# ----> 1 df = pd.read_csv("Flipkart_Mobile.csv")
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     608     kwds.update(kwds_defaults)
#     609
# ...

# %%
df = pd.read_csv('Flipkart Mobile.csv')

# %%
df.head()
# Out:
#    brand           model base_color  ROM  RAM processor  display_size  \
# 0  Apple       iPhone SE      Black   64    2     Water           4.7
# 1  Apple  iPhone 12 Mini        Red   64    4   Ceramic           5.4
# 2  Apple       iPhone SE        Red   64    2     Water           4.7
# 3  Apple       iPhone XR     Others   64    3       iOS           6.1
# 4  Apple       iPhone 12        Red  128    4   Ceramic           6.1
#
#   screen_size  num_rear_camera  num_front_camera  battery_capacity  ratings  \
# 0  Very Small                1                 1              1800      4.5
# 1       Small                2                 1              2815      4.5
# 2  Very Small                1                 1              1800      4.5
# 3      Medium                1                 1              2942      4.6
# 4      Medium                2                 1              2815      4.6
#
#    num_of_ratings  sales_price  discount_percent
# ...

# %%
plt.plot(df.model, df.battery_capacity)

# %%
plt.show()

# %%
plt.plot(df.model, df.RAM)

# %%
df.model
# Out:
# 0           iPhone SE
# 1      iPhone 12 Mini
# 2           iPhone SE
# 3           iPhone XR
# 4           iPhone 12
#             ...
# 425       Redmi 6 Pro
# 426       Redmi 6 Pro
# 427        Mi 11 Lite
# 428     Redmi 8A Dual
# 429       Redmi 6 Pro
# Name: model, Length: 430, dtype: object

# %%
df.brand
# Out:
# 0       Apple
# 1       Apple
# 2       Apple
# 3       Apple
# 4       Apple
#         ...
# 425    Xiaomi
# 426    Xiaomi
# 427    Xiaomi
# 428    Xiaomi
# 429    Xiaomi
# Name: brand, Length: 430, dtype: object

# %%
df.base_colour
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-63cd68998cf6> in <module>
# ----> 1 df.base_colour
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'base_colour'

# %%
df.base_color
# Out:
# 0       Black
# 1         Red
# 2         Red
# 3      Others
# 4         Red
#         ...
# 425     Black
# 426       Red
# 427    Others
# 428      Blue
# 429      Blue
# Name: base_color, Length: 430, dtype: object

# %%
df.base_color.iloc[3]
# Out:
# 'Others'

# %%
df.base_color.iloc[4]
# Out:
# 'Red'

# %%
df.brand == 'Apple'
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 425    False
# 426    False
# 427    False
# 428    False
# 429    False
# Name: brand, Length: 430, dtype: bool

# %%
realme = df[df.brand == 'realme']

# %%
realme
# Out:
# Empty DataFrame
# Columns: [brand, model, base_color, ROM, RAM, processor, display_size, screen_size, num_rear_camera, num_front_camera, battery_capacity, ratings, num_of_ratings, sales_price, discount_percent]
# Index: []

# %%
realme = data[df.brand == 'Apple']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-ab203fb3fdbf> in <module>
# ----> 1 realme = data[df.brand == 'Apple']
#
# NameError: name 'data' is not defined

# %%
realme = df[df.brand == 'realme']

# %%
realme
# Out:
# Empty DataFrame
# Columns: [brand, model, base_color, ROM, RAM, processor, display_size, screen_size, num_rear_camera, num_front_camera, battery_capacity, ratings, num_of_ratings, sales_price, discount_percent]
# Index: []

# %%
plt.plot(realme.model, realme.processor)

# %%
apple = df[df.brand == 'Apple']

# %%
apple
# Out:
#     brand           model base_color  ROM  RAM processor  display_size  \
# 0   Apple       iPhone SE      Black   64    2     Water           4.7
# 1   Apple  iPhone 12 Mini        Red   64    4   Ceramic           5.4
# 2   Apple       iPhone SE        Red   64    2     Water           4.7
# 3   Apple       iPhone XR     Others   64    3       iOS           6.1
# 4   Apple       iPhone 12        Red  128    4   Ceramic           6.1
# 5   Apple       iPhone 12       Blue   64    4   Ceramic           6.1
# 6   Apple       iPhone 12      White  128    4   Ceramic           6.1
# 7   Apple       iPhone 12      Green   64    4   Ceramic           6.1
# 8   Apple       iPhone 12       Blue  128    4   Ceramic           6.1
# 9   Apple       iPhone 12      Black  128    4   Ceramic           6.1
# 10  Apple  iPhone 12 Mini      Black   64    4   Ceramic           5.4
# 11  Apple       iPhone 12      Green  128    4   Ceramic           6.1
# ...

# %%
plt.plot(apple.model, apple.display_size)

# %%
plt.plot(apple.model, apple.rating)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-466d0c3d7fb4> in <module>
# ----> 1 plt.plot(apple.model, apple.rating)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'rating'

# %%
plt.plot(apple.model, apple.ratings)

# %%
plt.plot(apple.num_front_camera, apple.num_rear_camera)

# %%
plt.plot(apple.model, apple.sales_price)

# %%
plt.show()

# %%
df.head()
# Out:
#    brand           model base_color  ROM  RAM processor  display_size  \
# 0  Apple       iPhone SE      Black   64    2     Water           4.7
# 1  Apple  iPhone 12 Mini        Red   64    4   Ceramic           5.4
# 2  Apple       iPhone SE        Red   64    2     Water           4.7
# 3  Apple       iPhone XR     Others   64    3       iOS           6.1
# 4  Apple       iPhone 12        Red  128    4   Ceramic           6.1
#
#   screen_size  num_rear_camera  num_front_camera  battery_capacity  ratings  \
# 0  Very Small                1                 1              1800      4.5
# 1       Small                2                 1              2815      4.5
# 2  Very Small                1                 1              1800      4.5
# 3      Medium                1                 1              2942      4.6
# 4      Medium                2                 1              2815      4.6
#
#    num_of_ratings  sales_price  discount_percent
# ...

# %%
realme = df[df.brand == 'Realme']

# %%
realme
# Out:
#       brand      model base_color  ROM  RAM processor  display_size  \
# 112  Realme        C20       Blue   32    2  MediaTek           6.5
# 113  Realme        C20       Gray   32    2  MediaTek           6.5
# 114  Realme   C11 2021       Gray   32    2    Others           6.5
# 115  Realme   C11 2021       Blue   32    2    Others           6.5
# 116  Realme       C21Y      Black   64    4    Others           6.5
# ..      ...        ...        ...  ...  ...       ...           ...
# 245  Realme  Narzo 10A       Blue   32    3  MediaTek           6.5
# 246  Realme  Narzo 20A     Silver   32    3  Qualcomm           6.5
# 247  Realme   Narzo 10      Green  128    4  MediaTek           6.5
# 248  Realme   Narzo 10      White  128    4  MediaTek           6.5
# 249  Realme  Narzo 20A     Silver   64    4  Qualcomm           6.5
#
#     screen_size  num_rear_camera  num_front_camera  battery_capacity  ratings  \
# ...

# %%
plt.plot(realme.model, reamle.processor)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-53fc52b9a22b> in <module>
# ----> 1 plt.plot(realme.model, reamle.processor)
#
# NameError: name 'reamle' is not defined

# %%
plt.plot(reamle.model, realme.processor)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-de1afbb3000a> in <module>
# ----> 1 plt.plot(reamle.model, realme.processor)
#
# NameError: name 'reamle' is not defined

# %%
plt.plot(realme.model, realme.processor)

# %%
plt.plot(realme.ROM, realme.RAM)

# %%
plt.plot(realme.model, realme.sales_price)
plt.xlim([1,5])
plt.show()

# %%
realme
# Out:
#       brand      model base_color  ROM  RAM processor  display_size  \
# 112  Realme        C20       Blue   32    2  MediaTek           6.5
# 113  Realme        C20       Gray   32    2  MediaTek           6.5
# 114  Realme   C11 2021       Gray   32    2    Others           6.5
# 115  Realme   C11 2021       Blue   32    2    Others           6.5
# 116  Realme       C21Y      Black   64    4    Others           6.5
# ..      ...        ...        ...  ...  ...       ...           ...
# 245  Realme  Narzo 10A       Blue   32    3  MediaTek           6.5
# 246  Realme  Narzo 20A     Silver   32    3  Qualcomm           6.5
# 247  Realme   Narzo 10      Green  128    4  MediaTek           6.5
# 248  Realme   Narzo 10      White  128    4  MediaTek           6.5
# 249  Realme  Narzo 20A     Silver   64    4  Qualcomm           6.5
#
#     screen_size  num_rear_camera  num_front_camera  battery_capacity  ratings  \
# ...

# %%
plt.plot(realme.sales_price, realme.model)
plt.ylim([112,116])
plt.xlim([112,116])
plt.show()

# %%
plt.plot(realme.model, realme.sales_price)
plt.xlim([1,5])
plt.show()

# %%
plt.plot(realme.model, realme.sales_price)
plt.xlim([3,5])
plt.show()

# %%
plt.plot(realme.model, realme.display_size)
plt.plot(realme.model, realme.sales_price/10000)
plt.xlabel("Model Name")
plt.ylabel("display size")
plt.legend(["model, display", "model, price/10000"])
plt.xlim([1,5])
plt.show()

# %%
plt.plot(realme.model, realme.sales_price)
plt.arrow()
plt.xlim([1,5])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-50-f58040094dbf> in <module>
#       1 plt.plot(realme.model, realme.sales_price)
# ----> 2 plt.arrow()
#       3 plt.xlim([1,5])
#       4 plt.show()
#
# TypeError: arrow() missing 4 required positional arguments: 'x', 'y', 'dx', and 'dy'

# %%
plt.plot(realme.model, realme.sales_price)
plt.xlim([1,5])
plt.arrow(x,y)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-51-ebad024aed0d> in <module>
#       1 plt.plot(realme.model, realme.sales_price)
#       2 plt.xlim([1,5])
# ----> 3 plt.arrow(x,y)
#       4 plt.show()
#
# NameError: name 'x' is not defined

# %%
plt.plot(realme.model, realme.sales_price)
plt.xlim([1,5])
plt.arrow(2,4,2,2)
plt.show()

# %%
plt.bar(realme.model, realme.sales_price, color = "pink", width = 0.5)
plt.xlim([1,6])
plt.bar_label("C21")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-65-d03a5db8f1d4> in <module>
#       1 plt.bar(realme.model, realme.sales_price, color = "pink", width = 0.5)
#       2 plt.xlim([1,6])
# ----> 3 plt.bar_label("C21")
#       4 plt.show()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'bar_label'

# %%
plt.bar(realme.model, realme.display_size, color = 'black', width = 0.5)
plt.xlim([10,15])
plt.show()

# %%
realme
# Out:
#       brand      model base_color  ROM  RAM processor  display_size  \
# 112  Realme        C20       Blue   32    2  MediaTek           6.5
# 113  Realme        C20       Gray   32    2  MediaTek           6.5
# 114  Realme   C11 2021       Gray   32    2    Others           6.5
# 115  Realme   C11 2021       Blue   32    2    Others           6.5
# 116  Realme       C21Y      Black   64    4    Others           6.5
# ..      ...        ...        ...  ...  ...       ...           ...
# 245  Realme  Narzo 10A       Blue   32    3  MediaTek           6.5
# 246  Realme  Narzo 20A     Silver   32    3  Qualcomm           6.5
# 247  Realme   Narzo 10      Green  128    4  MediaTek           6.5
# 248  Realme   Narzo 10      White  128    4  MediaTek           6.5
# 249  Realme  Narzo 20A     Silver   64    4  Qualcomm           6.5
#
#     screen_size  num_rear_camera  num_front_camera  battery_capacity  ratings  \
# ...

# %%
plt.bar( realme.model,realme.battery_capacity, color = 'blue', width = 0.3)
plt.xlim([11,5])
plt.show()

# %%
realme.iloc[2]
# Out:
# brand                 Realme
# model               C11 2021
# base_color              Gray
# ROM                       32
# RAM                        2
# processor             Others
# display_size             6.5
# screen_size            Large
# num_rear_camera            1
# num_front_camera           1
# battery_capacity        5000
# ratings                  4.3
# num_of_ratings         19399
# sales_price             7299
# discount_percent        0.08
# Name: 114, dtype: object

# %%
realme.iloc[0]
# Out:
# brand                 Realme
# model                    C20
# base_color              Blue
# ROM                       32
# RAM                        2
# processor           MediaTek
# display_size             6.5
# screen_size            Large
# num_rear_camera            1
# num_front_camera           1
# battery_capacity        5000
# ratings                  4.4
# num_of_ratings        195910
# sales_price             7499
# discount_percent        0.06
# Name: 112, dtype: object

# %%
realme
# Out:
#       brand      model base_color  ROM  RAM processor  display_size  \
# 112  Realme        C20       Blue   32    2  MediaTek           6.5
# 113  Realme        C20       Gray   32    2  MediaTek           6.5
# 114  Realme   C11 2021       Gray   32    2    Others           6.5
# 115  Realme   C11 2021       Blue   32    2    Others           6.5
# 116  Realme       C21Y      Black   64    4    Others           6.5
# ..      ...        ...        ...  ...  ...       ...           ...
# 245  Realme  Narzo 10A       Blue   32    3  MediaTek           6.5
# 246  Realme  Narzo 20A     Silver   32    3  Qualcomm           6.5
# 247  Realme   Narzo 10      Green  128    4  MediaTek           6.5
# 248  Realme   Narzo 10      White  128    4  MediaTek           6.5
# 249  Realme  Narzo 20A     Silver   64    4  Qualcomm           6.5
#
#     screen_size  num_rear_camera  num_front_camera  battery_capacity  ratings  \
# ...

# %%
realme.ROM
# Out:
# 112     32
# 113     32
# 114     32
# 115     32
# 116     64
#       ...
# 245     32
# 246     32
# 247    128
# 248    128
# 249     64
# Name: ROM, Length: 138, dtype: int64

# %%
realme.model.iloc[5]
# Out:
# 'C21Y'

# %%
# here we can get battery capacity of any model

# %%
realme.battery_capacity.iloc[8]
# Out:
# 5000

# %%
plt.bar(realme.model, realme.sales_price, color = 'rbgyg', width = 0.3)
plt.xlim([1,5])
plt.show()
# Out:
# <ipython-input-93-bffcb879372e>:1: MatplotlibDeprecationWarning: Using a string of single character colors as a color sequence is deprecated since 3.2 and will be removed two minor releases later. Use an explicit list instead.
#   plt.bar(realme.model, realme.sales_price, color = 'rbgyg', width = 0.3)
