# %%
import pandas as pd

# %%
from matplotlib import pyplot as plt

# %%
x = [1,2,3]

# %%
y = [30,15,30]

# %%
plt.plot(x,y)
plt.xlabel("nos from 1 to 3")
plt.ylabel("nos from 10 to 30")
plt.show()
